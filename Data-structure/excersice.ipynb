# %% [markdown]
# Binary Tree

# %%
class Node:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
    
    def __repr__(self):
        return str(self.data)

# %%
root = Node(11)

# %%
type(root.data)
# Out:
# int

# %%
root = None 
node = Node(20)
# return node => 20
# self.__root = self._insert_rec(self.__root, data)
# => 20

# 25 insert
# root = Node(20) = node
# node.right = None, data = 25
# node.right이 node가 되고, 25가 data
node = Node(25)
# return node => 25 
print(node)
# Out:
# 25

# %%
class Node:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
    
    def __repr__(self):
        return str(self.data)

class BinarySearchTree:
    def __init__(self):
        self.__root = None 
    
    def insert(self, data):
        print('insert! =================', data)
        print(self.__root, data)
        self.__root = self._insert_rec(self.__root, data)
        print('after 1================')
        print(self.__root)

    def _insert_rec(self, node, data):
        if not node:
            node = Node(data)
            print('1) ================')
            print(node)
        else:
            if node.data > data:
                print('2) ================')
                print(node.data, data)
                print(node.left, data)
                node.left = self._insert_rec(node.left, data)
                print('after 2) ================')
                print(node.data, node.left)
            else:
                print('3) ================')
                print(node.data, data)
                print(node.right, data)
                node.right = self._insert_rec(node.right, data)
                print('after 3) ================')
                print(node.data, node.right)

        return node

# %%
bst = BinarySearchTree()
bst.insert(20)
bst.insert(25)
bst.insert(23)
# Out:
# insert! ================= 20
# None 20
# 1) ================
# 20
# after 1================
# 20
# insert! ================= 25
# 20 25
# 3) ================
# 20 25
# None 25
# 1) ================
# 25
# after 3) ================
# 20 25
# after 1================
# 20
# insert! ================= 23
# 20 23
# 3) ================
# 20 23
# 25 23
# 2) ================
# 25 23
# None 23
# 1) ================
# 23
# after 2) ================
# 25 23
# after 3) ================
# 20 25
# after 1================
# 20

# %%
import sys
sys.setrecursionlimit(10**6)

n = int(input())
tree = [[] for _ in range(n)]
for _ in range(n-1):
    p, c = map(int, input().split())
    tree[p].append(c)

values = list(map(int, input().split()))

n, tree, values
# Out:
# (8,
#  [[1, 2], [3, 4], [5, 6], [], [], [], [7], []],
#  [1, -5, -10, -1, 10, 20, -5, 20])

# %%
n = 8
tree =  [[1, 2], [3, 4], [5, 6], [], [], [], [7], []]
values = [1, -5, -10, -1, 10, 20, -5, 20]

# %%
def solution(tree, values):
    return get_totalsum(0, tree, values)

def get_totalsum(node, tree, values, depth=0):
    indent = "    " *depth
    print(f"{indent} > enter dfs({node})")

    total = values[node]
    print(f"{indent} start total = value[{node}] = {total}")

    for child in tree[node]:
        print(f"{indent} go to child {child}")

        gain = get_totalsum(child, tree, values, depth+1)

        print(f"{indent} back from child {child}, gain = {gain}")

        if gain > 0:
            print(f"{indent} gain > 0 -> add {gain}")
            total += gain 
        else:
            print(f"{indent} gain <= 0 -> skip")
    
    print(f"{indent} < return dfs({node}) = {total}\n")
    return total

solution(tree, values)
# Out:
#  > enter dfs(0)
#  start total = value[0] = 1
#  go to child 1
#      > enter dfs(1)
#      start total = value[1] = -5
#      go to child 3
#          > enter dfs(3)
#          start total = value[3] = -1
#          < return dfs(3) = -1
#
#      back from child 3, gain = -1
#      gain <= 0 -> skip
#      go to child 4
#          > enter dfs(4)
#          start total = value[4] = 10
#          < return dfs(4) = 10
#
#      back from child 4, gain = 10
#      gain > 0 -> add 10
#      < return dfs(1) = 5
#
#  back from child 1, gain = 5
#  gain > 0 -> add 5
#  go to child 2
#      > enter dfs(2)
#      start total = value[2] = -10
#      go to child 5
#          > enter dfs(5)
#          start total = value[5] = 20
#          < return dfs(5) = 20
#
#      back from child 5, gain = 20
#      gain > 0 -> add 20
#      go to child 6
#          > enter dfs(6)
#          start total = value[6] = -5
#          go to child 7
#              > enter dfs(7)
#              start total = value[7] = 20
#              < return dfs(7) = 20
#
#          back from child 7, gain = 20
#          gain > 0 -> add 20
#          < return dfs(6) = 15
#
#      back from child 6, gain = 15
#      gain > 0 -> add 15
#      < return dfs(2) = 25
#
#  back from child 2, gain = 25
#  gain > 0 -> add 25
#  < return dfs(0) = 31
# 31

# %%
def dfs(node):
    res = values[node]

    for child in tree[node]:
        res += max(dfs(child), 0)

    return res

dfs(0)
# Out:
# 31

# %%
import sys
sys.setrecursionlimit

# %%
def solution(n, A, edges):
    E = list([] for _ in range(n))
    for p, c in edges:
        E[p].append(c)
        
    return min(solve(0,0,A,E), solve(0,1,A,E))

def solve(u, color, A, E):
    ret = A[u][color]
    for v in E[u]:
        ret += solve(v, 1-color, A, E)
    
    return ret

n = int(input())
edges = list(list(map(int, input().split())) for _ in range(n-1))
A = list(list(map(int, input().split())) for _ in range(n))
print(solution(n, A, edges))
# Out:
# 310
